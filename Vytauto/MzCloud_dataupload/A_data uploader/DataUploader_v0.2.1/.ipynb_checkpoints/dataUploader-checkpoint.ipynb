# %% [markdown]
# # Instructions
#
# - Upload compound masterlist file from shared location
# - Click read masterlist button
# - default locations:
#     - Vilnius: //ltvil-freenas5.thermofisher.lt/PTVG_Data/DATA/mzCloud/Data/Production/
#     - Austin:

# %%
import lib
# Out:
# HBox(children=(VBox(children=(FileUpload(value={}, description='UploadMasterList'), Button(description='ReadDa…
# HBox(children=(VBox(children=(Dropdown(options=('----',), value='----'), Button(description='Prepare data', ic…
# Copying NP-000205-neg.raw
# Copying NP-000205-pos.raw
# Copying NP-000684-neg.raw
# Copying NP-000684-pos.raw
# Copying NP-000798-neg.raw
# Copying NP-000798-pos.raw
# Copying NP-000939-neg.raw
# Copying NP-000939-pos.raw
# Copying NP-002204-neg.raw
# Copying NP-003912-neg.raw
# Copying NP-003912-pos.raw
# Copying NP-004266-neg.raw
# Copying NP-004266-pos.raw
# Copying NP-005093-neg.raw
# Copying NP-005093-pos.raw
# Copying NP-005755-neg.raw
# Copying NP-005996-neg.raw
# Copying NP-005996-pos.raw
# Copying NP-007389-neg.raw
# Copying NP-007389-pos.raw
# Copying NP-008239-neg.raw
# Copying NP-008239-pos.raw
# Copying NP-008339-neg-2.raw
# Copying NP-008339-neg.raw
# Copying NP-008339-pos.raw
# Copying NP-008665-neg.raw
# Copying NP-008665-pos.raw
# Copying NP-008869-neg.raw
# Copying NP-008869-pos.raw
# Copying NP-012184-neg.raw
# Copying NP-012184-pos.raw
# Copying NP-012895-neg.raw
# Copying NP-012895-pos.raw
# Copying NP-013011-neg.raw
# Copying NP-013011-pos.raw
# Copying NP-015097-neg.raw
# Copying NP-015097-pos.raw
# Copying NP-015119-neg.raw
# Copying NP-015119-pos.raw
# Copying NP-016032-neg.raw
# Copying NP-016032-pos.raw
# Copying NP-016222-neg.raw
# Copying NP-016222-pos.raw
# Copying NP-016237-neg.raw
# Copying NP-016237-pos.raw
# Copying NP-016257-pos.raw
# Copying NP-016257_neg-neg.raw
# Copying NP-016978-neg.raw
# Copying NP-016978-pos.raw
# Copying NP-017040-neg.raw
# Copying NP-017040-pos.raw
# Copying NP-019266-neg.raw
# Copying NP-019266-pos.raw
# Copying NP-019417-neg.raw
# Copying NP-019417-pos.raw
# Copying NP-019535-neg.raw
# Copying NP-019535-pos.raw
# Copying NP-019956-neg.raw
# Copying NP-019956-pos.raw
# Copying NP-019960-neg.raw
# Copying NP-019960-pos.raw
# Copying NP-019965-neg.raw
# Copying NP-019965-pos.raw
# Copying NP-020084-neg.raw
# Copying NP-020084-pos.raw
# Copying NP-020575-neg.raw
# Copying NP-020575-pos.raw
# Copying NP-021981-neg.raw
# Copying NP-021981-pos.raw
# Copying NP-022038-neg.raw
# Copying NP-022038-pos.raw
# Copying NP-022061-neg.raw
# Copying NP-022061-pos.raw
# Copying NP-022125-pos.raw
# Copying NP-022125_neg-neg.raw
# Copying NP-022038-neg.raw
# Copying NP-022319-pos.raw
# Copying NP-022385-neg.raw
# Copying NP-022385-pos.raw
# Copying NP-022393-neg.raw
# Copying NP-022393-pos.raw
# Copying NP-022737-neg.raw
# Copying NP-022737-pos.raw
# Copying NP-022763-neg.raw
# Copying NP-022763-pos.raw
# Copying NP-023116-neg.raw
# Copying NP-023116-pos.raw
# Copying NP-023195-neg.raw
# Copying NP-023195-pos.raw
# Copying NP-023196-pos.raw
# Copying NP-023196_neg-neg.raw
# Copying NP-023242-neg.raw
# Copying NP-023242-pos.raw
# Copying NP-023300-neg.raw
# Copying NP-023300-pos.raw
# Copying NP-023327-neg (2).raw
# Copying NP-023327-neg.raw
# Copying NP-023327-pos.raw
# Copying NP-023874-neg.raw
# Copying NP-023874-pos.raw
# Copying NP-023910-neg.raw
# Copying NP-023910-pos.raw
# Copying NP-024036-pos.raw
# Copying NP-024242-neg.raw
# Copying NP-024242-pos.raw
# Copying NP-024246-neg.raw
# Copying NP-024246-pos.raw
# Copying NP-024297-neg.raw
# Copying NP-024297-pos.raw
# Copying NP-024341-pos.raw
# Copying NP-024341_neg-neg.raw
# Copying NP-024347-neg.raw
# Copying NP-024347-pos.raw
# Copying NP-024366-neg.raw
# Copying NP-024366-pos.raw
# Copying NP-024442-neg.raw
# Copying NP-024442-pos.raw
# Copying NP-024459-neg.raw
# Copying NP-024459-pos.raw
# Copying NP-024463-neg.raw
# Copying NP-024463-pos.raw
# Copying NP-024483-neg.raw
# Copying NP-024483-pos.raw
# Copying NP-024497-neg.raw
# Copying NP-024497-pos.raw
# Copying NP-024544-neg.raw
# Copying NP-024544-pos.raw
# Copying NP-024548-neg.raw
# Copying NP-024548-pos.raw
# Copying NP-024549-neg.raw
# Copying NP-024549-pos.raw
# Copying NP-024552-neg.raw
# Copying NP-024552-pos.raw
# Copying NP-024557-neg.raw
# Copying NP-024557-pos.raw
# Copying NP-024559-neg.raw
# Copying NP-024559-pos.raw
# Copying NP-024571-neg.raw
# Copying NP-024571-pos.raw
# Copying NP-024650-neg.raw
# Copying NP-024650-pos.raw
# Copying NP-024701-neg (2).raw
# Copying NP-024701-neg.raw
# Copying NP-024701-pos.raw
# Copying NP-024759-neg.raw
# Copying NP-024759-pos.raw
# Copying NP-024760-neg.raw
# Copying NP-024760-pos.raw
# Copying NP-024834-neg.raw
# Copying NP-024834-pos.raw
# Copying NP-024837-neg.raw
# Copying NP-024837-pos.raw
# Copying NP-024872-pos.raw
# Copying NP-024874-neg.raw
# Copying NP-024874-pos.raw
# Copying NP-024897-neg.raw
# Copying NP-024897-pos.raw
# Copying NP-024940-neg.raw
# Copying NP-024940-pos.raw
# Copying NP-000205-neg.ccomx
# Copying NP-000205-pos.ccomx
# Copying NP-000684-neg.ccomx
# Copying NP-000684-pos.ccomx
# Copying NP-000798-neg.ccomx
# Copying NP-000798-pos.ccomx
# Copying NP-000939-neg.ccomx
# Copying NP-000939-pos.ccomx
# Copying NP-002204-neg.ccomx
# Copying NP-003912-neg.ccomx
# Copying NP-003912-pos.ccomx
# Copying NP-004266-neg.ccomx
# Copying NP-004266-pos.ccomx
# Copying NP-005093-neg.ccomx
# Copying NP-005093-pos.ccomx
# Copying NP-005755-neg.ccomx
# Copying NP-005996-neg.ccomx
# Copying NP-005996-pos.ccomx
# Copying NP-007389-neg.ccomx
# Copying NP-007389-pos.ccomx
# Copying NP-008239-neg.ccomx
# Copying NP-008239-pos.ccomx
# Copying NP-008339-neg-2.ccomx
# Copying NP-008339-neg.ccomx
# Copying NP-008339-pos.ccomx
# Copying NP-008665-neg.ccomx
# Copying NP-008665-pos.ccomx
# Copying NP-008869-neg.ccomx
# Copying NP-008869-pos.ccomx
# Copying NP-012184-neg.ccomx
# Copying NP-012184-pos.ccomx
# Copying NP-012895-neg.ccomx
# Copying NP-012895-pos.ccomx
# Copying NP-013011-neg.ccomx
# Copying NP-013011-pos.ccomx
# Copying NP-015097-neg.ccomx
# Copying NP-015097-pos.ccomx
# Copying NP-015119-neg.ccomx
# Copying NP-015119-pos.ccomx
# Copying NP-016032-neg.ccomx
# Copying NP-016032-pos.ccomx
# Copying NP-016222-neg.ccomx
# Copying NP-016222-pos.ccomx
# Copying NP-016237-neg.ccomx
# Copying NP-016237-pos.ccomx
# Copying NP-016257-pos.ccomx
# Copying NP-016257_neg-neg.ccomx
# Copying NP-016978-neg.ccomx
# Copying NP-016978-pos.ccomx
# Copying NP-017040-neg.ccomx
# Copying NP-017040-pos.ccomx
# Copying NP-019266-neg.ccomx
# Copying NP-019266-pos.ccomx
# Copying NP-019417-neg.ccomx
# Copying NP-019417-pos.ccomx
# Copying NP-019535-neg.ccomx
# Copying NP-019535-pos.ccomx
# Copying NP-019956-neg.ccomx
# Copying NP-019956-pos.ccomx
# Copying NP-019960-neg.ccomx
# Copying NP-019960-pos.ccomx
# Copying NP-019965-neg.ccomx
# Copying NP-019965-pos.ccomx
# Copying NP-020084-neg.ccomx
# Copying NP-020084-pos.ccomx
# Copying NP-020575-neg.ccomx
# Copying NP-020575-pos.ccomx
# Copying NP-021981-neg.ccomx
# Copying NP-021981-pos.ccomx
# Copying NP-022038-neg.ccomx
# Copying NP-022038-pos.ccomx
# Copying NP-022061-neg.ccomx
# Copying NP-022061-pos.ccomx
# Copying NP-022125-pos.ccomx
# Copying NP-022125_neg-neg.ccomx
# Copying NP-022038-neg.ccomx
# Copying NP-022319-pos.ccomx
# Copying NP-022385-neg.ccomx
# Copying NP-022385-pos.ccomx
# Copying NP-022393-neg.ccomx
# Copying NP-022393-pos.ccomx
# Copying NP-022737-neg.ccomx
# Copying NP-022737-pos.ccomx
# Copying NP-022763-neg.ccomx
# Copying NP-022763-pos.ccomx
# Copying NP-023116-neg.ccomx
# Copying NP-023116-pos.ccomx
# Copying NP-023195-neg.ccomx
# Copying NP-023195-pos.ccomx
# Copying NP-023196-pos.ccomx
# Copying NP-023196_neg-neg.ccomx
# Copying NP-023242-neg.ccomx
# Copying NP-023242-pos.ccomx
# Copying NP-023300-neg.ccomx
# Copying NP-023300-pos.ccomx
# Copying NP-023327-neg (2).ccomx
# Copying NP-023327-neg.ccomx
# Copying NP-023327-pos.ccomx
# Copying NP-023874-neg.ccomx
# Copying NP-023874-pos.ccomx
# Copying NP-023910-neg.ccomx
# Copying NP-023910-pos.ccomx
# Copying NP-024036-pos.ccomx
# Copying NP-024242-neg.ccomx
# Copying NP-024242-pos.ccomx
# Copying NP-024246-neg.ccomx
# Copying NP-024246-pos.ccomx
# Copying NP-024297-neg.ccomx
# Copying NP-024297-pos.ccomx
# Copying NP-024341-pos.ccomx
# Copying NP-024341_neg-neg.ccomx
# Copying NP-024347-neg.ccomx
# Copying NP-024347-pos.ccomx
# Copying NP-024366-neg.ccomx
# Copying NP-024366-pos.ccomx
# Copying NP-024442-neg.ccomx
# Copying NP-024442-pos.ccomx
# Copying NP-024459-neg.ccomx
# Copying NP-024459-pos.ccomx
# Copying NP-024463-neg.ccomx
# Copying NP-024463-pos.ccomx
# Copying NP-024483-neg.ccomx
# Copying NP-024483-pos.ccomx
# Copying NP-024497-neg.ccomx
# Copying NP-024497-pos.ccomx
# Copying NP-024544-neg.ccomx
# Copying NP-024544-pos.ccomx
# Copying NP-024548-neg.ccomx
# Copying NP-024548-pos.ccomx
# Copying NP-024549-neg.ccomx
# Copying NP-024549-pos.ccomx
# Copying NP-024552-neg.ccomx
# Copying NP-024552-pos.ccomx
# Copying NP-024557-neg.ccomx
# Copying NP-024557-pos.ccomx
# Copying NP-024559-neg.ccomx
# Copying NP-024559-pos.ccomx
# Copying NP-024571-neg.ccomx
# Copying NP-024571-pos.ccomx
# Copying NP-024650-neg.ccomx
# Copying NP-024650-pos.ccomx
# Copying NP-024701-neg (2).ccomx
# Copying NP-024701-neg.ccomx
# Copying NP-024701-pos.ccomx
# Copying NP-024759-neg.ccomx
# Copying NP-024759-pos.ccomx
# Copying NP-024760-neg.ccomx
# Copying NP-024760-pos.ccomx
# Copying NP-024834-neg.ccomx
# Copying NP-024834-pos.ccomx
# Copying NP-024837-neg.ccomx
# Copying NP-024837-pos.ccomx
# Copying NP-024872-pos.ccomx
# Copying NP-024874-neg.ccomx
# Copying NP-024874-pos.ccomx
# Copying NP-024897-neg.ccomx
# Copying NP-024897-pos.ccomx
# Copying NP-024940-neg.ccomx
# Copying NP-024940-pos.ccomx

# %%
lib.app.comp_names
# Out:
#           cID                         name  \
# 0   NP-000205  KOZGOKPCYLCJDK-UHFFFAOYSA-N
# 1   NP-000684  YJGVMLPVUAXIQN-UHFFFAOYSA-N
# 2   NP-000798  PLAPMLGJVGLZOV-UHFFFAOYSA-N
# 3   NP-000939  NFWKVWVWBFBAOV-IPNZSQQUSA-N
# 4   NP-002204  NFIQKUQYFSTGFU-DAUWJCTESA-N
# ..        ...                          ...
# 75  NP-024837  RUBLIKRGQGISNL-UHFFFAOYSA-N
# 76  NP-024872  XTYQZLHDXJNHMO-VQHVLOKHSA-N
# 77  NP-024874  FMXUSNAWMLGDCZ-UHFFFAOYSA-N
# 78  NP-024897  AFONGXIPOGRCST-ONEGZZNKSA-N
# 79  NP-024940  TWLHPMIWLQNHPM-UHFFFAOYSA-N
#
#                                            iupac_name
# 0   3-[5,7-dihydroxy-2-(4-hydroxyphenyl)-4-oxo-chr...
# 1   10-methyl-10-(4-methylpent-3-enyl)-11-(3-oxobu...
# 2   5-hydroxy-9-(3,4,5-trimethoxyphenyl)-5a,6,8a,9...
# 3   2-(3,4-dihydroxyphenyl)-5,7-dihydroxy-8-[3,4,5...
# 4   rac-(1R,4aS)-7-isopropyl-1,4a-dimethyl-2,3,4,9...
# ..                                                ...
# 75  [rac-(3S,8R,9E,12R)-5-(hydroxymethyl)-10-methy...
# 76  2',3',4-trihydroxy-1',1',4'a,6'-tetramethyl-sp...
# 77  (9E)-5,12-dihydroxy-16-isobutyl-4-methoxy-5,14...
# 78  4-[2-(1H-indol-3-yl)ethylamino]-4-oxo-butanoic...
# 79  6,8-dihydroxy-8a-methyl-5-[(E)-prop-1-enyl]-5,...
#
# [80 rows x 3 columns]
